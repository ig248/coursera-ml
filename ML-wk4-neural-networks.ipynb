% %% [markdown]
% # Coursera ML - Week 4
%
% https://www.coursera.org/learn/machine-learning/home/week/4

% %% [markdown]
% ## Non-linear hypotheses
%
% For $n=100$ features, total number of quadratic features $\sim n^2/2 = 5000$
%
% Cubic features $\sim O(n^3) \sim 170000$ etc.
%
% Building non-linear classifiers this way is expensive!!!
%
% E.g. image recognition/classification

% %% [markdown]
% ## Neural networks
%
% popular 80s-90s, decline late 90s, recent resurgance
%
% ### Neurons
% Inputs - multiple: *dendrites*
%
% Output - single: *axon*
%
% ### Neuron model: Logistic unit
% ![_auto_0](attachment:_auto_0)
%
% Inputs $x_i$, weights (parameters) $\theta_i$
%
% Bias unit $x_0$
%
% Sigmoid (logistic) **activation function**
%
% Output $$h_\theta = g(\theta^T x) = \frac{1}{1+e^{-\theta^T x}} $$
%
% ### Neural network model
% ![_auto_1](attachment:_auto_1)
%
% $a_i^{(j)}$ - activation of unit $i$ in layer $j$
%
% $\theta^{(j)}_{ki}$ - weights from layer $j$ ($a_i^{(j)}$) to layer $j+1$ ($a_k^{(j+1)}$)
%
% $$a_k^{(j+1)} = g\left( z_k^{(j+1)} \right) = g\left( \sum_i \theta^{(j)}_{ki} a_i^{(j)} \right)$$
%
% $s_j$ neurons in layer $j$ $\Rightarrow \theta^{(j)}_{ki} \in \mathbb{R}^{s_{j+1}\times(s_j + 1)}$, i.e. an $s_{j+1}\times(s_j + 1)$ matrix

% %% [markdown]
% ## Examples
%
% ### Binary logic
% $x_1, x_2 \in \{0,1\}$
%
% #### AND
% ![_auto_0](attachment:_auto_0)
%
% #### OR
% ![_auto_2](attachment:_auto_2)
%
% #### NOT
% ![_auto_3](attachment:_auto_3)
%
% #### XNOR
% Combine:
% ![_auto_5](attachment:_auto_5)
%
% to get:
% ![_auto_6](attachment:_auto_6)

% %% [markdown]
% ## Multi-class classification
% One-vs-all
%
% Training set:
% $$(x^{(i)}, y^{(i)})$$
%
% $x^{(i)}$ - e.g. images
% $y^{(i)} \in \mathbb{R}^{n}$ - **$n$ classes**, e.g. $y^{(i)}_j = \delta_{ij}$
%
% E.g. "car" = ${1,0,0,0}^T$, "pedestrian" = ${0,1,0,0}^T$, etc.
